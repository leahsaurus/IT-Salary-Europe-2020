# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_palette("ch:s=-.2,r=.6")

# %%
df = pd.read_csv("./IT_Salary_Survey_EU_2020.csv");
print(df.head(10));
# Out:
#              Timestamp   Age  Gender       City                    Position   \
# 0  13/12/2020 18:25:45  25.0  Female     Berlin            Software Engineer
# 1  30/11/2020 13:26:02  24.0    Male     Berlin            Backend Developer
# 2  26/11/2020 22:41:33  20.0    Male     Berlin             Mobile Developer
# 3  27/11/2020 14:55:13  29.0  Female    Cologne                  ML Engineer
# 4  25/11/2020 12:27:53  30.0    Male     Berlin                Data Engineer
# 5  25/11/2020 15:53:21  40.0    Male  Cupertino            Software Engineer
# 6  25/11/2020 13:16:43  38.0    Male     Berlin  Freelance AI lead / advisor
# 7  30/11/2020 14:36:32  35.0    Male     Berlin                Data Engineer
# 8  26/11/2020 09:38:35  35.0    Male     Berlin            Software Engineer
# 9  24/11/2020 15:05:21  39.0    Male     Berlin              Product Manager
#
#    Total years of experience  Years of experience in Germany  Seniority level  \
# ...

# %%
df.shape
# Out:
# (1246, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1246 non-null   object
#  1   Age                                                                                                                      1219 non-null   float64
#  2   Gender                                                                                                                   1236 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Total years of experience  Years of experience in Germany  \
# count  1219.000000                1230.000000                     1214.000000
# mean     32.502051                   8.777317                        3.728204
# std       5.546841                   5.270374                        3.639083
# min      20.000000                   0.000000                        0.000000
# 25%      29.000000                   5.000000                        1.000000
# 50%      32.000000                   8.000000                        3.000000
# 75%      35.000000                  12.000000                        5.000000
# max      66.000000                  40.000000                       30.000000
#
#        Yearly brutto salary (without bonus and stocks) in EUR  \
# count                                       1.246000e+03
# mean                                        8.072982e+07
# std                                         2.832985e+09
# ...

# %%
df.isnull().any()
# Out:
# Timestamp                                                                                                                  False
# Age                                                                                                                         True
# Gender                                                                                                                      True
# City                                                                                                                       False
# Position                                                                                                                    True
# Total years of experience                                                                                                   True
# Years of experience in Germany                                                                                              True
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
sns.boxplot(y=df['Age']);

# %%
df2 = pd.DataFrame();
df2['Age'] = df['Age'].fillna(int(df['Age'].median()));

# %%
df2
# Out:
#        Age
# 0     25.0
# 1     24.0
# 2     20.0
# 3     29.0
# 4     30.0
# ...    ...
# 1241  32.0
# 1242  37.0
# 1243  32.0
# 1244  32.0
# 1245  32.0
#
# [1246 rows x 1 columns]

# %%
df['Age'] = df['Age'].fillna(int(df['Age'].median()));

# %%
sns.boxplot(y=df['Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country'])
# Out:
# <AxesSubplot:ylabel='Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country'>

# %%
df['Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country'] = df['Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country'].fillna(0);

# %%
sns.boxplot(y=df['Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week']);

# %%
df['Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week'] = df['Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week'].fillna(0);

# %%
df
# Out:
#                 Timestamp   Age  Gender        City          Position   \
# 0     13/12/2020 18:25:45  25.0  Female      Berlin  Software Engineer
# 1     30/11/2020 13:26:02  24.0    Male      Berlin  Backend Developer
# 2     26/11/2020 22:41:33  20.0    Male      Berlin   Mobile Developer
# 3     27/11/2020 14:55:13  29.0  Female     Cologne        ML Engineer
# 4     25/11/2020 12:27:53  30.0    Male      Berlin      Data Engineer
# ...                   ...   ...     ...         ...                ...
# 1241  25/11/2020 03:27:34  32.0     NaN      Berlin                NaN
# 1242  25/11/2020 21:10:17  37.0    Male  Stuttgart   Backend Developer
# 1243  20/12/2020 00:30:53  32.0     NaN      Berlin                NaN
# 1244  20/12/2020 00:31:23  32.0     NaN      Berlin                NaN
# 1245       8/1/2021 12:52  32.0     NaN      Munich                NaN
#
#       Total years of experience  Years of experience in Germany  \
# ...

# %%
df[['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR']]\
= df[['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR']].apply(pd.to_numeric)
print(df.dtypes)
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                        float64
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                  float64
# Years of experience in Germany                                                                                             float64
# ...

# %%
sns.boxplot(y=df['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR']);

# %%
df['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'] = df['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'].fillna(0);

# %%
df
# Out:
#                 Timestamp   Age  Gender        City          Position   \
# 0     13/12/2020 18:25:45  25.0  Female      Berlin  Software Engineer
# 1     30/11/2020 13:26:02  24.0    Male      Berlin  Backend Developer
# 2     26/11/2020 22:41:33  20.0    Male      Berlin   Mobile Developer
# 3     27/11/2020 14:55:13  29.0  Female     Cologne        ML Engineer
# 4     25/11/2020 12:27:53  30.0    Male      Berlin      Data Engineer
# ...                   ...   ...     ...         ...                ...
# 1241  25/11/2020 03:27:34  32.0     NaN      Berlin                NaN
# 1242  25/11/2020 21:10:17  37.0    Male  Stuttgart   Backend Developer
# 1243  20/12/2020 00:30:53  32.0     NaN      Berlin                NaN
# 1244  20/12/2020 00:31:23  32.0     NaN      Berlin                NaN
# 1245       8/1/2021 12:52  32.0     NaN      Munich                NaN
#
#       Total years of experience  Years of experience in Germany  \
# ...

# %%
df[['Total years of experience', 'Years of experience in Germany', \
    'Annual bonus+stocks one year ago. Only answer if staying in same country', \
    'Number of vacation days', 'Yearly bonus + stocks in EUR']] = df[['Total years of experience', 'Years of experience in Germany', \
                                       'Annual bonus+stocks one year ago. Only answer if staying in same country', \
                                       'Number of vacation days', 'Yearly bonus + stocks in EUR']].apply(pd.to_numeric)
print(df.dtypes)
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                        float64
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                  float64
# Years of experience in Germany                                                                                             float64
# ...

# %%
df[['Yearly bonus + stocks in EUR']] = df[['Yearly bonus + stocks in EUR']].apply(pd.to_numeric)

# %%
df.isnull().any()
# Out:
# Timestamp                                                                                                                  False
# Age                                                                                                                        False
# Gender                                                                                                                      True
# City                                                                                                                       False
# Position                                                                                                                    True
# Total years of experience                                                                                                   True
# Years of experience in Germany                                                                                              True
# ...

# %%
fig, ax = plt.subplots(2,3, figsize=(20, 20))
sns.boxplot(y=df['Total years of experience'], ax=ax[0,0])
sns.boxplot(y=df['Years of experience in Germany'], ax=ax[0,1])
sns.boxplot(y=df['Yearly brutto salary (without bonus and stocks) in EUR'], ax=ax[0,2])
sns.boxplot(y=df['Annual bonus+stocks one year ago. Only answer if staying in same country'], ax=ax[1,0])
sns.boxplot(y=df['Number of vacation days'], ax=ax[1,1])
sns.boxplot(y=df['Yearly bonus + stocks in EUR'], ax=ax[1,2])
plt.show()

# %%
df['Total years of experience'] = df['Total years of experience'].fillna(int(df['Total years of experience'].median()));
df['Years of experience in Germany'] = df['Years of experience in Germany'].fillna(int(df['Years of experience in Germany'].median()));
df['Yearly brutto salary (without bonus and stocks) in EUR'] = df['Yearly brutto salary (without bonus and stocks) in EUR'].fillna(0);
df['Annual bonus+stocks one year ago. Only answer if staying in same country'] = df['Annual bonus+stocks one year ago. Only answer if staying in same country'].fillna(0);
df['Number of vacation days'] = df['Number of vacation days'].fillna(0);
df['Yearly bonus + stocks in EUR'] = df['Yearly bonus + stocks in EUR'].fillna(0);

# %%
df.isnull().any()
# Out:
# Timestamp                                                                                                                  False
# Age                                                                                                                        False
# Gender                                                                                                                      True
# City                                                                                                                       False
# Position                                                                                                                    True
# Total years of experience                                                                                                  False
# Years of experience in Germany                                                                                             False
# ...

# %%
fig, ax = plt.subplots(4,3, figsize=(80, 80))
sns.countplot(x="Gender", data=df, ax=ax[0,0])
sns.countplot(x="Position ", data=df, ax=ax[0,1])
sns.countplot(x="Seniority level", data=df, ax=ax[0,2])
sns.countplot(x="Your main technology / programming language", data=df, ax=ax[1,0])
sns.countplot(x="Other technologies/programming languages you use often", data=df, ax=ax[1,1])
sns.countplot(x="Employment status", data=df, ax=ax[1,2])
sns.countplot(x="Сontract duration", data=df, ax=ax[2,0])
sns.countplot(x="Main language at work", data=df, ax=ax[2,1])
sns.countplot(x="Company size", data=df, ax=ax[2,2])
sns.countplot(x="Company type", data=df, ax=ax[3,0])
sns.countplot(x="Have you lost your job due to the coronavirus outbreak?", data=df, ax=ax[3,1])
sns.countplot(x="Gender", data=df, ax=ax[3,2])
plt.xticks(rotation=45);
plt.show()

# %%
df['Gender'] = df['Gender'].replace(np.nan, "Other");
df['Position '] = df['Position '].replace(np.nan, "Other");
df['Seniority level'] = df['Seniority level'].replace(np.nan, "Full Time Employee");
df['Your main technology / programming language'] = df['Your main technology / programming language'].replace(np.nan, "Not Specified");
df['Other technologies/programming languages you use often'] = df['Other technologies/programming languages you use often'].replace(np.nan, "NOt Specified");
df['Employment status'] = df['Employment status'].replace(np.nan, "Other");
df['Сontract duration'] = df['Сontract duration'].replace(np.nan, "NOt Specified");
df['Main language at work'] = df['Main language at work'].replace(np.nan, "Other");
df['Company size'] = df['Company size'].replace(np.nan, "Not Specified");
df['Company type'] = df['Company type'].replace(np.nan, "Other");
df['Have you lost your job due to the coronavirus outbreak?'] = df['Have you lost your job due to the coronavirus outbreak?'].replace(np.nan, "Other Condition");

# %%
df.isnull()
# Out:
#       Timestamp    Age  Gender   City  Position   Total years of experience  \
# 0         False  False   False  False      False                      False
# 1         False  False   False  False      False                      False
# 2         False  False   False  False      False                      False
# 3         False  False   False  False      False                      False
# 4         False  False   False  False      False                      False
# ...         ...    ...     ...    ...        ...                        ...
# 1241      False  False   False  False      False                      False
# 1242      False  False   False  False      False                      False
# 1243      False  False   False  False      False                      False
# 1244      False  False   False  False      False                      False
# 1245      False  False   False  False      False                      False
#
#       Years of experience in Germany  Seniority level  \
# ...

# %%
print("\nDescribe datatype information:\n");
df.info();
print("\n\nDescribe null value composition:\n");
df.isnull().any()
# Out:
# Describe datatype information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1246 entries, 0 to 1245
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1246 non-null   object
#  1   Age                                                                                                                      1246 non-null   float64
#  2   Gender                                                                                                                   1246 non-null   object
# ...

# %% [markdown]
# # After removing NaN cells and correcting data types

# %% [markdown]
# ### For Object Data Types

# %%
fig, ax = plt.subplots(4,3, figsize=(80, 80))
sns.countplot(x="Gender", data=df, ax=ax[0,0])
sns.countplot(x="Position ", data=df, ax=ax[0,1])
sns.countplot(x="Seniority level", data=df, ax=ax[0,2])
sns.countplot(x="Your main technology / programming language", data=df, ax=ax[1,0])
sns.countplot(x="Other technologies/programming languages you use often", data=df, ax=ax[1,1])
sns.countplot(x="Employment status", data=df, ax=ax[1,2])
sns.countplot(x="Сontract duration", data=df, ax=ax[2,0])
sns.countplot(x="Main language at work", data=df, ax=ax[2,1])
sns.countplot(x="Company size", data=df, ax=ax[2,2])
sns.countplot(x="Company type", data=df, ax=ax[3,0])
sns.countplot(x="Have you lost your job due to the coronavirus outbreak?", data=df, ax=ax[3,1])
sns.countplot(x="City", data=df, ax=ax[3,2])
plt.xticks(rotation=45);
plt.show()

# %% [markdown]
# ### For Float64 Data Types

# %%
fig, ax = plt.subplots(3,3, figsize=(20, 20))
sns.boxplot(y=df['Total years of experience'], ax=ax[0,0])
sns.boxplot(y=df['Years of experience in Germany'], ax=ax[0,1])
sns.boxplot(y=df['Yearly brutto salary (without bonus and stocks) in EUR'], ax=ax[0,2])
sns.boxplot(y=df['Annual bonus+stocks one year ago. Only answer if staying in same country'], ax=ax[1,0])
sns.boxplot(y=df['Number of vacation days'], ax=ax[1,1])
sns.boxplot(y=df['Yearly bonus + stocks in EUR'], ax=ax[1,2])
sns.boxplot(y=df['Age'], ax=ax[2,0])
sns.boxplot(y=df['Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country'], ax=ax[2,1])
sns.boxplot(y=df['Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'], ax=ax[2,2])
plt.show()

# %%
sns.boxplot(y=df['Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week']);

# %% [markdown]
# # CLEANED DATASET

# %%
df
# Out:
#                 Timestamp   Age  Gender        City          Position   \
# 0     13/12/2020 18:25:45  25.0  Female      Berlin  Software Engineer
# 1     30/11/2020 13:26:02  24.0    Male      Berlin  Backend Developer
# 2     26/11/2020 22:41:33  20.0    Male      Berlin   Mobile Developer
# 3     27/11/2020 14:55:13  29.0  Female     Cologne        ML Engineer
# 4     25/11/2020 12:27:53  30.0    Male      Berlin      Data Engineer
# ...                   ...   ...     ...         ...                ...
# 1241  25/11/2020 03:27:34  32.0   Other      Berlin              Other
# 1242  25/11/2020 21:10:17  37.0    Male  Stuttgart   Backend Developer
# 1243  20/12/2020 00:30:53  32.0   Other      Berlin              Other
# 1244  20/12/2020 00:31:23  32.0   Other      Berlin              Other
# 1245       8/1/2021 12:52  32.0   Other      Munich              Other
#
#       Total years of experience  Years of experience in Germany  \
# ...

# %%
df.iloc[:, 0:12]
# Out:
#                 Timestamp   Age  Gender        City          Position   \
# 0     13/12/2020 18:25:45  25.0  Female      Berlin  Software Engineer
# 1     30/11/2020 13:26:02  24.0    Male      Berlin  Backend Developer
# 2     26/11/2020 22:41:33  20.0    Male      Berlin   Mobile Developer
# 3     27/11/2020 14:55:13  29.0  Female     Cologne        ML Engineer
# 4     25/11/2020 12:27:53  30.0    Male      Berlin      Data Engineer
# ...                   ...   ...     ...         ...                ...
# 1241  25/11/2020 03:27:34  32.0   Other      Berlin              Other
# 1242  25/11/2020 21:10:17  37.0    Male  Stuttgart   Backend Developer
# 1243  20/12/2020 00:30:53  32.0   Other      Berlin              Other
# 1244  20/12/2020 00:31:23  32.0   Other      Berlin              Other
# 1245       8/1/2021 12:52  32.0   Other      Munich              Other
#
#       Total years of experience  Years of experience in Germany  \
# ...

# %%
df.iloc[:, 12:24]
# Out:
#       Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                   0.0
# 3                                           500000000.0
# 4                                               75000.0
# ...                                                 ...
# 1241                                                0.0
# 1242                                                0.0
# 1243                                                0.0
# 1244                                                0.0
# 1245                                                0.0
#
#       Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                                   0.0
# 1                                                   0.0
# ...

# %% [markdown]
# # WORKING ON DATASET

# %%
df.describe()
# Out:
#                Age  Total years of experience  Years of experience in Germany  \
# count  1246.000000                1246.000000                     1246.000000
# mean     32.491172                   8.767335                        3.709502
# std       5.486852                   5.237130                        3.593860
# min      20.000000                   0.000000                        0.000000
# 25%      29.000000                   5.000000                        1.000000
# 50%      32.000000                   8.000000                        3.000000
# 75%      35.000000                  12.000000                        5.000000
# max      66.000000                  40.000000                       30.000000
#
#        Yearly brutto salary (without bonus and stocks) in EUR  \
# count                                       1.246000e+03
# mean                                        8.072982e+07
# std                                         2.832985e+09
# ...

# %% [markdown]
# ## Total Correlation Matrix

# %%
print("\nCorrelation Matrix is: ");
total_corr_matrix = df.corr();
total_corr_matrix
# Out:
# Correlation Matrix is:
#                                                          Age  \
# Age                                                 1.000000
# Total years of experience                           0.713884
# Years of experience in Germany                      0.535727
# Yearly brutto salary (without bonus and stocks)... -0.002626
# Yearly bonus + stocks in EUR                       -0.018029
# Annual brutto salary (without bonus and stocks)... -0.017421
# Annual bonus+stocks one year ago. Only answer i... -0.016433
# Number of vacation days                             0.024702
# Have you been forced to have a shorter working ...  0.030087
# Have you received additional monetary support f...  0.029929
#
#                                                     Total years of experience  \
# Age                                                                  0.713884
# Total years of experience                                            1.000000
# ...

# %% [markdown]
# #### ! Strong Correlation: Age | Total Years of Experience
#
# #### ! Very Strong Correlation: Yearly bonus + stocks in EUR | Annual brutto salary (without bonus and stocks) one                                                     year ago. Only answer if staying in the same country,
# ####                                          - Yearly bonus + stocks in EUR | Annual bonus+stocks one year ago. Only answer if                                                       staying in same country
# ####                                          -  Annual bonus+stocks one year ago. Only answer if staying in same country | Annual                                                    brutto salary (without bonus and stocks) one year ago. Only answer if staying in the                                                      same country

# %%
sns.heatmap(total_corr_matrix, cmap='GnBu');

# %%
print("\nCorrelation Matrix is: ");
total_corr_matrix2 = df.corr(method='spearman');
total_corr_matrix2
# Out:
# Correlation Matrix is:
#                                                          Age  \
# Age                                                 1.000000
# Total years of experience                           0.678030
# Years of experience in Germany                      0.434032
# Yearly brutto salary (without bonus and stocks)...  0.322047
# Yearly bonus + stocks in EUR                        0.026565
# Annual brutto salary (without bonus and stocks)...  0.316150
# Annual bonus+stocks one year ago. Only answer i...  0.106215
# Number of vacation days                             0.153948
# Have you been forced to have a shorter working ...  0.051077
# Have you received additional monetary support f...  0.040988
#
#                                                     Total years of experience  \
# Age                                                                  0.678030
# Total years of experience                                            1.000000
# ...

# %%
sns.heatmap(total_corr_matrix2, cmap='YlGn');

# %%
def mahalanobis(x=None, data=None, cov=None):
    x_minus_mu = x - np.mean(data)
    if not cov:
        cov = np.cov(data.values.T)
    inv_covmat = sp.linalg.inv(cov)
    left_term = np.dot(x_minus_mu, inv_covmat)
    mahal = np.dot(left_term, x_minus_mu.T)
    return mahal.diagonal()

df_m = df_m[Age	Total years of experience	Years of experience in Germany	Yearly brutto salary (without bonus and stocks) in EUR	Yearly bonus + stocks in EUR	Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country	Annual bonus+stocks one year ago. Only answer if staying in same country	Number of vacation days	Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week	Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR]]
df_m['mahalanobis_dist'] = mahalanobis(x=df_m, data=df_m[['X', 'Y', 'Z']])
print(df_m2)

# %% [markdown]
# # Chi-Square Testing

# %% [markdown]
# ### Gender & Position

# %%
import scipy.stats as stats;

# %%
pd.crosstab(df["Gender"], df["Position "], margins=True)
# Out:
# Position   AI Management  Account Managet  Agile Coach  Analyst  \
# Gender
# Diverse                0                0            0        0
# Female                 0                1            0        1
# Male                   1                0            1        0
# Other                  0                0            0        0
# All                    1                1            1        1
#
# Position   Analytics engineer  Application Consultant  Architect  Architect   \
# Gender
# Diverse                     0                       0          0           0
# Female                      1                       1          0           0
# Male                        0                       0          1           1
# Other                       0                       0          0           0
# All                         1                       1          1           1
#
# Position   BI Analyst   BI Consultant  ...  VP Engineering  XR Developer  \
# ...

# %%
df_cross1 = pd.crosstab(df["Gender"], df["Position "], margins=False)
df_cross1
# Out:
# Position   AI Management  Account Managet  Agile Coach  Analyst  \
# Gender
# Diverse                0                0            0        0
# Female                 0                1            0        1
# Male                   1                0            1        0
# Other                  0                0            0        0
#
# Position   Analytics engineer  Application Consultant  Architect  Architect   \
# Gender
# Diverse                     0                       0          0           0
# Female                      1                       1          0           0
# Male                        0                       0          1           1
# Other                       0                       0          0           0
#
# Position   BI Analyst   BI Consultant  ...  Testmanager  VP Engineering  \
# Gender                                 ...
# Diverse              0              0  ...            0               0
# ...

# %%
print(stats.chi2_contingency(df_cross1));
# Out:
# (648.8507207169341, 3.876585592696022e-10, 441, array([[1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 2.76083467e-01, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 4.81540931e-03, 1.60513644e-03, 1.60513644e-03,
#         8.02568218e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 4.81540931e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.28410915e-02,
#         3.21027287e-03, 1.60513644e-03, 4.01284109e-02, 1.60513644e-03,
#         1.76565008e-01, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 2.56821830e-02, 9.14927769e-02, 1.60513644e-03,
#         1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-02,
# ...

# %% [markdown]
# ### Gender & Seniority Level

# %%
pd.crosstab(df["Gender"], df["Seniority level"], margins=True)
# Out:
# Seniority level  C-Level  C-level executive manager  CTO  Director  \
# Gender
# Diverse                0                          0    0         0
# Female                 0                          0    0         0
# Male                   1                          1    1         1
# Other                  0                          0    0         0
# All                    1                          1    1         1
#
# Seniority level  Entry level  Full Time Employee  Head  Intern  Junior  Key  \
# Gender
# Diverse                    0                   0     1       0       0    0
# Female                     0                   1     1       0      24    0
# Male                       1                   7    41       1      53    1
# Other                      0                   4     0       0       0    0
# All                        1                  12    43       1      77    1
#
# Seniority level  ...  Principal  Self employed  Senior  Student  VP  \
# ...

# %%
df_cross2 = pd.crosstab(df["Gender"], df["Seniority level"], margins=False)
df_cross2
# Out:
# Seniority level  C-Level  C-level executive manager  CTO  Director  \
# Gender
# Diverse                0                          0    0         0
# Female                 0                          0    0         0
# Male                   1                          1    1         1
# Other                  0                          0    0         0
#
# Seniority level  Entry level  Full Time Employee  Head  Intern  Junior  Key  \
# Gender
# Diverse                    0                   0     1       0       0    0
# Female                     0                   1     1       0      24    0
# Male                       1                   7    41       1      53    1
# Other                      0                   4     0       0       0    0
#
# Seniority level  ...  No level   Principal  Self employed  Senior  Student  \
# Gender           ...
# Diverse          ...          0          0              0       0        0
# ...

# %%
print(stats.chi2_contingency(df_cross2));
# Out:
# (273.21530985680545, 4.2509481490359684e-26, 69, array([[1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 1.92616372e-02, 6.90208668e-02, 1.60513644e-03,
#         1.23595506e-01, 1.60513644e-03, 2.66452648e-01, 1.60513644e-03,
#         5.84269663e-01, 1.60513644e-03, 1.60513644e-03, 4.81540931e-03,
#         1.60513644e-03, 9.05296950e-01, 1.60513644e-03, 1.60513644e-03,
#         1.60513644e-03, 1.60513644e-03, 1.60513644e-03, 1.60513644e-03],
#        [1.52487961e-01, 1.52487961e-01, 1.52487961e-01, 1.52487961e-01,
#         1.52487961e-01, 1.82985554e+00, 6.55698234e+00, 1.52487961e-01,
#         1.17415730e+01, 1.52487961e-01, 2.53130016e+01, 1.52487961e-01,
#         5.55056180e+01, 1.52487961e-01, 1.52487961e-01, 4.57463884e-01,
#         1.52487961e-01, 8.60032103e+01, 1.52487961e-01, 1.52487961e-01,
#         1.52487961e-01, 1.52487961e-01, 1.52487961e-01, 1.52487961e-01],
# ...

# %% [markdown]
# ### City & Yearly bonus + stocks in EUR

# %%
df['Yearly_Bonus_Group'] = ['0-50000' if x>=0 and x<=50000 else '50000-100000' if x>50000 and x<=100000 else '100000-200000' if x>100000 and x<=200000 else 'Excess Amount' for x in df['Yearly bonus + stocks in EUR']]

# %%
df.iloc[:, 18:25]
# Out:
#        Company size Company type  \
# 0          101-1000      Product
# 1          up to 10      Startup
# 2             1000+      Product
# 3          up to 10      Startup
# 4             1000+      Product
# ...             ...          ...
# 1241  Not Specified        Other
# 1242  Not Specified        Other
# 1243  Not Specified        Other
# 1244  Not Specified        Other
# 1245  Not Specified        Other
#
#      Have you lost your job due to the coronavirus outbreak?  \
# 0                                                    No
# 1                                                    No
# 2                                                   Yes
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 1241                                    Other Condition
# 1242                                                 No
# ...

# %%
pd.crosstab(df["City"], df["Yearly_Bonus_Group"], margins=True)
# Out:
# Yearly_Bonus_Group  0-50000  100000-200000  50000-100000  Excess Amount   All
# City
# Aachen                    2              0             0              0     2
# Amsterdam                 7              0             2              0     9
# Ansbach                   1              0             0              0     1
# Barcelona                 2              0             0              0     2
# Basel                     1              0             0              0     1
# ...                     ...            ...           ...            ...   ...
# Würzburg                  1              0             0              0     1
# Zurich                    3              1             1              0     5
# Zürich                    1              0             0              0     1
# warsaw                    1              0             0              0     1
# All                    1113             22           108              3  1246
#
# [119 rows x 5 columns]

# %%
df_cross3 = pd.crosstab(df["City"], df["Yearly_Bonus_Group"], margins=False)
df_cross3
# Out:
# Yearly_Bonus_Group  0-50000  100000-200000  50000-100000  Excess Amount
# City
# Aachen                    2              0             0              0
# Amsterdam                 7              0             2              0
# Ansbach                   1              0             0              0
# Barcelona                 2              0             0              0
# Basel                     1              0             0              0
# ...                     ...            ...           ...            ...
# Wroclaw                   1              0             0              0
# Würzburg                  1              0             0              0
# Zurich                    3              1             1              0
# Zürich                    1              0             0              0
# warsaw                    1              0             0              0
#
# [118 rows x 4 columns]

# %%
print(stats.chi2_contingency(df_cross3));
# Out:
# (587.7804990094401, 3.3145228156801217e-14, 351, array([[1.78651685e+00, 3.53130016e-02, 1.73354735e-01, 4.81540931e-03],
#        [8.03932584e+00, 1.58908507e-01, 7.80096308e-01, 2.16693419e-02],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
#        [1.78651685e+00, 3.53130016e-02, 1.73354735e-01, 4.81540931e-03],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
#        [6.08308989e+02, 1.20240770e+01, 5.90272873e+01, 1.63964687e+00],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
#        [2.67977528e+00, 5.29695024e-02, 2.60032103e-01, 7.22311396e-03],
#        [2.67977528e+00, 5.29695024e-02, 2.60032103e-01, 7.22311396e-03],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
#        [8.93258427e-01, 1.76565008e-02, 8.66773676e-02, 2.40770465e-03],
# ...

# %% [markdown]
# ### Company Size & Covid 19 Reception in EUR

# %%
pd.crosstab(df["Company size"], df["Have you lost your job due to the coronavirus outbreak?"], margins=True)
# Out:
# Have you lost your job due to the coronavirus outbreak?    No  \
# Company size
# 1000+                                                     423
# 101-1000                                                  387
# 51-100                                                    136
# Not Specified                                               6
# Nov-50                                                    160
# up to 10                                                   52
# All                                                      1164
#
# Have you lost your job due to the coronavirus outbreak?  Other Condition  Yes  \
# Company size
# 1000+                                                                  6   19
# 101-1000                                                               2   14
# 51-100                                                                 0   11
# Not Specified                                                         12    0
# ...

# %%
df_cross4 = pd.crosstab(df["Company size"], df["Have you lost your job due to the coronavirus outbreak?"], margins=False)
df_cross4
# Out:
# Have you lost your job due to the coronavirus outbreak?   No  Other Condition  \
# Company size
# 1000+                                                    423                6
# 101-1000                                                 387                2
# 51-100                                                   136                0
# Not Specified                                              6               12
# Nov-50                                                   160                0
# up to 10                                                  52                0
#
# Have you lost your job due to the coronavirus outbreak?  Yes
# Company size
# 1000+                                                     19
# 101-1000                                                  14
# 51-100                                                    11
# Not Specified                                              0
# Nov-50                                                     9
# ...

# %%
print(stats.chi2_contingency(df_cross4));
# Out:
# (508.6289627285874, 6.320549114450398e-103, 10, array([[4.18516854e+02, 7.19101124e+00, 2.22921348e+01],
#        [3.76478331e+02, 6.46869984e+00, 2.00529695e+01],
#        [1.37325843e+02, 2.35955056e+00, 7.31460674e+00],
#        [1.68154093e+01, 2.88924559e-01, 8.95666132e-01],
#        [1.57878010e+02, 2.71268058e+00, 8.40930979e+00],
#        [5.69855538e+01, 9.79133226e-01, 3.03531300e+00]]))

# %% [markdown]
# ### Employment status & Main coding language

# %%
pd.crosstab(df["Employment status"], df["Your main technology / programming language"], margins=True)
# Out:
# Your main technology / programming language         -  --  .NET  .Net  \
# Employment status
# Company Director                                    0   0     0     0
# Founder                                             0   0     0     0
# Full-time employee                                  1   1    12     3
# Full-time position, part-time position, & self-...  0   0     0     0
# Intern                                              0   0     0     0
# Other                                               0   0     0     0
# Part-time employee                                  0   0     0     0
# Self-employed (freelancer)                          0   0     1     0
# Werkstudent                                         0   0     0     0
# Working Student                                     0   0     0     0
# full-time, but 32 hours per week (it was my req...  0   0     0     0
# working student                                     0   0     0     0
# ...

# %%
df_cross5 = pd.crosstab(df["Employment status"], df["Your main technology / programming language"], margins=False)
df_cross5
# Out:
# Your main technology / programming language         -  --  .NET  .Net  \
# Employment status
# Company Director                                    0   0     0     0
# Founder                                             0   0     0     0
# Full-time employee                                  1   1    12     3
# Full-time position, part-time position, & self-...  0   0     0     0
# Intern                                              0   0     0     0
# Other                                               0   0     0     0
# Part-time employee                                  0   0     0     0
# Self-employed (freelancer)                          0   0     1     0
# Werkstudent                                         0   0     0     0
# Working Student                                     0   0     0     0
# full-time, but 32 hours per week (it was my req...  0   0     0     0
# working student                                     0   0     0     0
#
# ...

# %%
print(stats.chi2_contingency(df_cross5));
# Out:
# (4338.246749377227, 9.020977716544483e-70, 2805, array([[8.02568218e-04, 8.02568218e-04, 1.04333868e-02, ...,
#         1.60513644e-03, 8.02568218e-04, 8.02568218e-04],
#        [2.40770465e-03, 2.40770465e-03, 3.13001605e-02, ...,
#         4.81540931e-03, 2.40770465e-03, 2.40770465e-03],
#        [9.51845907e-01, 9.51845907e-01, 1.23739968e+01, ...,
#         1.90369181e+00, 9.51845907e-01, 9.51845907e-01],
#        ...,
#        [8.02568218e-04, 8.02568218e-04, 1.04333868e-02, ...,
#         1.60513644e-03, 8.02568218e-04, 8.02568218e-04],
#        [8.02568218e-04, 8.02568218e-04, 1.04333868e-02, ...,
#         1.60513644e-03, 8.02568218e-04, 8.02568218e-04],
#        [8.02568218e-04, 8.02568218e-04, 1.04333868e-02, ...,
#         1.60513644e-03, 8.02568218e-04, 8.02568218e-04]]))
